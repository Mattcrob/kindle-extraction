# %%
# Install required packages
# venv\scripts\activate
#  pip install -r requirements.txt
# 1pip install jupyter
# Out:
#   Cell In[1], line 4
#     pip install jupyter
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import re
from datetime import datetime

# %%
# Read in the file
with open('My Clippings.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Give me all non-empty chunks, trimmed of whitespace
highlights = [h.strip() for h in text.split('==========') if h.strip()]
no_highlights = len(highlights)

print("Number of highlights: ", no_highlights)
print("Example highlight:", "\n", highlights[0])
# Out:
# Number of highlights:  96
# Example highlight:
#  ﻿The Lord of the Rings: The classic fantasy masterpiece
# - Your Highlight at location 290-290 | Added on Tuesday, 13 September 2022 20:57:50
#
# mythology

# %%
# Filter to french language books
pd_highlights = pd.DataFrame(highlights, columns=['highlight'])
french_highlights = pd_highlights[pd_highlights['highlight'].str.contains('français|French', case=False, na=False)]

print("Number of French highlights found:", len(french_highlights))
print(french_highlights.iloc[0]['highlight'])  # Print first French highlight as example
# Out:
# Number of French highlights found: 64
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 8 | location 37-37 | Added on Friday, 14 July 2023 10:49:49
#
# ressemblait à Byron — par la tête, car il était irréprochable quant

# %%
# Separate meta data from actual highlight

# Title (French Edition) (Author)
# - Your Highlight on page x | location x-y | Added on datetime.
# Highlight
clipping = french_highlights.iloc[6]['highlight']
print("Highlight: \n", french_highlights.iloc[7]['highlight'], "\n\n----------",)

title = re.match(r"^(.*?)\s*\(", clipping).group(1)
print("Title: ", title)

author = re.match(r".*\((.*?)\)", clipping).group(1)
print("Author: ", author)

page = re.search(r"page\s+(\d+)", clipping).group(1)
print("Page: ", page)

location = re.search(r"Location\s+(\d+-\d+)", clipping).group(1)
print("Location: ", location)

timestamp_str = re.search(r"Added on (.*)", clipping).group(1)
print("Timestamp: ", timestamp_str)

timestamp = datetime.strptime(timestamp_str, "%A, %d %B %Y %H:%M:%S")
print(timestamp)

highlight = clipping.strip().split("\n")[3]
print("Highlight: ", highlight)
# Out:
# Highlight:
#  Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 40-40 | Added on Saturday, 18 October 2025 08:16:19
#
# dirigeait
#
# ----------
# Title:  Harry Potter à L'école des Sorciers
# Author:  Rowling, J.K.
# Page:  7
# Location:  39-40
# Timestamp:  Saturday, 18 October 2025 08:16:07
# 2025-10-18 08:16:07
# Highlight:  sornettes.

# %%
# Split out sections of clipping
def split_clipping(clipping):
    import re
    from datetime import datetime

    title = re.match(r"^(.*?)\s*\(", clipping).group(1)
    author = re.match(r".*\((.*?)\)", clipping).group(1)
    page = re.search(r"page\s+(\d+)", clipping).group(1)
    location = re.search(r"location\s+(\d+-\d+)", clipping, re.IGNORECASE)
    timestamp_str = re.search(r"Added on (.*)", clipping).group(1)
    timestamp = datetime.strptime(timestamp_str, "%A, %d %B %Y %H:%M:%S")
    highlight = clipping.strip().split("\n")[3]

    return{
        "title" : title,
        "author" : author,
        "page" : page,
        "location" : location,
        "timestamp" : timestamp,
        "highlight" : highlight
    }

test = split_clipping(french_highlights.iloc[6]['highlight'])
print(test)
# Out:
# {'title': "Harry Potter à L'école des Sorciers", 'author': 'Rowling, J.K.', 'page': '7', 'location': <re.Match object; span=(98, 112), match='Location 39-40'>, 'timestamp': datetime.datetime(2025, 10, 18, 8, 16, 7), 'highlight': 'sornettes.'}

# %%
clean_highlights = french_highlights['highlight'].apply(split_clipping)

# Convert the resulting Series of dictionaries into a DataFrame
df_clean_highlights = pd.DataFrame(parsed.tolist())

# Inspect
print(df_clean_highlights.head())

# %%
all_parsed = []

for clipping in french_highlights['highlight']:
    #print(clipping)
    parsed_item = split_clipping(clipping)
    all_parsed.append(parsed_item)

df_parsed = pd.DataFrame(all_parsed)
# Out:
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 8 | location 37-37 | Added on Friday, 14 July 2023 10:49:49
#
# ressemblait à Byron — par la tête, car il était irréprochable quant
# <class 'str'>
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 10 | location 55-55 | Added on Friday, 14 July 2023 10:56:13
#
# cherchait au-delà.
# <class 'str'>
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 45 | location 305-306 | Added on Wednesday, 23 August 2023 21:59:18
#
# , disséquée, avec autant de passion et d'ardeur que s'il se fût
# <class 'str'>
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 46 | location 315-316 | Added on Tuesday, 29 August 2023 21:05:03
#
# déposée aux archives du Reform-Club. Certains gentlemen osaient
# <class 'str'>
# Le tour du monde en quatre-vingts jours (French Edition) (Verne, Jules)
# - Your Highlight on page 57 | location 401-401 | Added on Friday, 15 September 2023 20:37:13
#
# et onze heures sonnaient quand le steamer vint mouiller
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 38-38 | Added on Saturday, 18 October 2025 08:15:53
#
# quiconque
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 39-40 | Added on Saturday, 18 October 2025 08:16:07
#
# sornettes.
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 40-40 | Added on Saturday, 18 October 2025 08:16:19
#
# dirigeait
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 40-40 | Added on Saturday, 18 October 2025 08:16:26
#
# perceuses.
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 41-41 | Added on Saturday, 18 October 2025 08:17:25
#
# quant
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 41-41 | Added on Saturday, 18 October 2025 08:17:41
#
# cou,
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 42-42 | Added on Saturday, 18 October 2025 08:18:23
#
# par-dessus
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 42-43 | Added on Saturday, 18 October 2025 08:18:44
#
# clôtures
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 7 | Location 44-45 | Added on Saturday, 18 October 2025 08:19:10
#
# craignaient
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 48-48 | Added on Saturday, 18 October 2025 08:20:37
#
# éloignés
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 49-49 | Added on Saturday, 18 October 2025 08:21:19
#
# malheur
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 50-50 | Added on Saturday, 18 October 2025 08:22:05
#
# de tenir les Potter à distance
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 51-51 | Added on Saturday, 18 October 2025 08:22:36
#
# le petit Dudley se mette à fréquenter un enfant comme celui-là.
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 51-52 | Added on Saturday, 18 October 2025 08:22:44
#
# s’éveillèrent,
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 52-53 | Added on Saturday, 18 October 2025 08:23:08
#
# laissait prévoir que des choses étranges et mystérieuses allaient
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 53-53 | Added on Saturday, 18 October 2025 08:23:49
#
# fredonnait
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 53-53 | Added on Saturday, 18 October 2025 08:24:01
#
# en nouant
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 54-54 | Added on Saturday, 18 October 2025 08:24:14
#
# badin
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location 54-54 | Added on Saturday, 18 October 2025 08:24:18
#
# potins
# <class 'str'>
# Harry Potter à L'école des Sorciers (French Edition) (Rowling, J.K.)
# - Your Highlight on page 8 | Location